# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows',10000)

# %% [markdown]
# ## Problem Statement

# %%
# Your client is a meal delivery company which operates in multiple cities.
# They have various fulfillment centers in these cities for dispatching meal orders to their customers.
# The client wants you to help these centers with demand forecasting for upcoming weeks so that these centers will
# plan the stock of raw materials accordingly.

# The replenishment of majority of raw materials is done on weekly basis and since the raw material is perishable,
# the procurement planning is of utmost importance.
# Secondly, staffing of the centers is also one area wherein accurate demand forecasts are really helpful.
# Given the following information, the task is to predict the
# demand for the next 10 weeks (Weeks: 146-155) for the center-meal combinations in the test set:  

# Historical data of demand for a product-center combination (Weeks: 1 to 145)
# Product(Meal) features such as category, sub-category, current price and discount
# Information for fulfillment center like center area, city information etc.

# %% [markdown]
# ## Data set

# %%
df = pd.read_csv(r'C:\Users\shubham\Downloads\train.csv')
df.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                      0                  0         177
# 1                      0                  0         270
# 2                      0                  0         189
# 3                      0                  0          54
# 4                      0                  0          40

# %%
df.shape
# Out:
# (456548, 9)

# %%
df1 = pd.read_csv(r'C:\Users\shubham\Downloads\meal_info.csv')
df1.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
df1.category.nunique()
# Out:
# 14

# %%
df1.isnull().sum()
# Out:
# meal_id     0
# category    0
# cuisine     0
# dtype: int64

# %%
df2 = pd.read_csv(r'C:\Users\shubham\Downloads\fulfilment_center_info.csv')
df2.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
df2.isnull().sum()
# Out:
# center_id      0
# city_code      0
# region_code    0
# center_type    0
# op_area        0
# dtype: int64

# %%
df2.shape
# Out:
# (77, 5)

# %%
dfm = pd.merge(df,df1,on='meal_id')

# %%
dfm.isnull().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# category                 0
# cuisine                  0
# dtype: int64

# %%
dfm
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1040403     1         24     1885          136.83      136.83
# 2       1103215     1         11     1885          136.83      136.83
# 3       1034383     1         83     1885          121.31      120.31
# 4       1118999     1         32     1885          114.52      113.52
# ...         ...   ...        ...      ...             ...         ...
# 456543  1458599   145         65     2104          582.03      582.03
# 456544  1417199   145        110     2104          582.03      581.03
# 456545  1434028   145         68     2104          582.03      581.03
# 456546  1205895   145         51     2104          641.23      640.23
# 456547  1443704   145         61     2104          581.03      582.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                           0                  0         177  Beverages
# 1                           0                  0        1498  Beverages
# 2                           0                  0         959  Beverages
# 3                           0                  1        1025  Beverages
# 4                           0                  1         445  Beverages
# ...                       ...                ...         ...        ...
# 456543                      0                  0         134       Fish
# 456544                      0                  0          28       Fish
# 456545                      0                  0          40       Fish
# 456546                      0                  0          69       Fish
# 456547                      0                  0          27       Fish
#
#             cuisine
# 0              Thai
# 1              Thai
# 2              Thai
# 3              Thai
# 4              Thai
# ...             ...
# 456543  Continental
# 456544  Continental
# 456545  Continental
# 456546  Continental
# 456547  Continental
#
# [456548 rows x 11 columns]

# %% [markdown]
# ## Merging tables

# %%
df_f = pd.merge(dfm,df2,on='center_id')

# %%
df_f
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1018704     2         55     1885          135.83      152.29
# 2       1196273     3         55     1885          132.92      133.92
# 3       1116527     4         55     1885          135.86      134.86
# 4       1343872     5         55     1885          146.50      147.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1437396   141         61     2104          583.03      630.53
# 456544  1060716   142         61     2104          581.03      582.03
# 456545  1029231   143         61     2104          583.03      581.03
# 456546  1141147   144         61     2104          582.03      581.03
# 456547  1443704   145         61     2104          581.03      582.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                           0                  0         177  Beverages
# 1                           0                  0         323  Beverages
# 2                           0                  0          96  Beverages
# 3                           0                  0         163  Beverages
# 4                           0                  0         215  Beverages
# ...                       ...                ...         ...        ...
# 456543                      0                  1          13       Fish
# 456544                      0                  0          42       Fish
# 456545                      0                  0          40       Fish
# 456546                      0                  0          53       Fish
# 456547                      0                  0          27       Fish
#
#             cuisine  city_code  region_code center_type  op_area
# 0              Thai        647           56      TYPE_C      2.0
# 1              Thai        647           56      TYPE_C      2.0
# 2              Thai        647           56      TYPE_C      2.0
# 3              Thai        647           56      TYPE_C      2.0
# 4              Thai        647           56      TYPE_C      2.0
# ...             ...        ...          ...         ...      ...
# 456543  Continental        473           77      TYPE_A      4.5
# 456544  Continental        473           77      TYPE_A      4.5
# 456545  Continental        473           77      TYPE_A      4.5
# 456546  Continental        473           77      TYPE_A      4.5
# 456547  Continental        473           77      TYPE_A      4.5
#
# [456548 rows x 15 columns]

# %%
df_f.describe()
# Out:
#                  id           week      center_id        meal_id  \
# count  4.565480e+05  456548.000000  456548.000000  456548.000000
# mean   1.250096e+06      74.768771      82.105796    2024.337458
# std    1.443548e+05      41.524956      45.975046     547.420920
# min    1.000000e+06       1.000000      10.000000    1062.000000
# 25%    1.124999e+06      39.000000      43.000000    1558.000000
# 50%    1.250184e+06      76.000000      76.000000    1993.000000
# 75%    1.375140e+06     111.000000     110.000000    2539.000000
# max    1.499999e+06     145.000000     186.000000    2956.000000
#
#        checkout_price     base_price  emailer_for_promotion  \
# count   456548.000000  456548.000000          456548.000000
# mean       332.238933     354.156627               0.081152
# std        152.939723     160.715914               0.273069
# min          2.970000      55.350000               0.000000
# 25%        228.950000     243.500000               0.000000
# 50%        296.820000     310.460000               0.000000
# 75%        445.230000     458.870000               0.000000
# max        866.270000     866.270000               1.000000
#
#        homepage_featured     num_orders      city_code    region_code  \
# count       456548.00000  456548.000000  456548.000000  456548.000000
# mean             0.10920     261.872760     601.553399      56.614566
# std              0.31189     395.922798      66.195914      17.641306
# min              0.00000      13.000000     456.000000      23.000000
# 25%              0.00000      54.000000     553.000000      34.000000
# 50%              0.00000     136.000000     596.000000      56.000000
# 75%              0.00000     324.000000     651.000000      77.000000
# max              1.00000   24299.000000     713.000000      93.000000
#
#              op_area
# count  456548.000000
# mean        4.083590
# std         1.091686
# min         0.900000
# 25%         3.600000
# 50%         4.000000
# 75%         4.500000
# max         7.000000

# %%
df_final = df_f.copy(deep = True)

# %% [markdown]
# ## changing datatypes

# %%
df_f['emailer_for_promotion']=df_f['emailer_for_promotion'].astype('object')
df_f['homepage_featured']=df_f['homepage_featured'].astype('object')
df_f['region_code']=df_f['region_code'].astype('object')
df_f['city_code']=df_f['city_code'].astype('object')
df_f['center_id']=df_f['center_id'].astype('object')

# As they all are having category in them

# %%
num_col = df_f.select_dtypes(include = np.number).columns
num_col
# Out:
# Index(['id', 'week', 'meal_id', 'checkout_price', 'base_price', 'num_orders',
#        'op_area'],
#       dtype='object')

# %%
cat_col = df_f.select_dtypes(exclude = np.number).columns
cat_col
# Out:
# Index(['center_id', 'emailer_for_promotion', 'homepage_featured', 'category',
#        'cuisine', 'city_code', 'region_code', 'center_type'],
#       dtype='object')

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456548 entries, 0 to 456547
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  object
#  3   meal_id                456548 non-null  int64
#  4   checkout_price         456548 non-null  float64
#  5   base_price             456548 non-null  float64
#  6   emailer_for_promotion  456548 non-null  object
#  7   homepage_featured      456548 non-null  object
#  8   num_orders             456548 non-null  int64
#  9   category               456548 non-null  object
#  10  cuisine                456548 non-null  object
#  11  city_code              456548 non-null  object
#  12  region_code            456548 non-null  object
#  13  center_type            456548 non-null  object
#  14  op_area                456548 non-null  float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 55.7+ MB

# %%
df_f.op_area.value_counts()
# Out:
# 4.0    52548
# 3.9    48533
# 3.8    40080
# 4.4    26060
# 4.5    25688
# 2.8    25503
# 4.1    23346
# 7.0    20686
# 4.8    18648
# 3.4    17258
# 3.6    16821
# 5.1    13366
# 4.2    12608
# 2.7    12430
# 3.0    11184
# 2.0     9512
# 6.7     7046
# 6.3     7015
# 5.6     6993
# 3.7     6801
# 3.5     6666
# 3.2     6333
# 5.0     6164
# 5.3     6053
# 4.6     5983
# 4.7     5975
# 2.4     5021
# 2.9     4712
# 1.9     4083
# 0.9     3432
# Name: op_area, dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(20,15))
num_col
t = 1
for i in num_col:
    plt.subplot(4,3,t)
    sns.distplot(df_f[i])
    t+=1
plt.show()


# 1. Most of the orders having base price range in between 200 to 400.
# 1. Checkout price ranges varies similar to base price with a little
# discount.
# 1. Maximum orders placed from restaurant are having operation area
# within 3.5 to 4.5 SqKm.

# %%
df_f.skew()

# homepage_featured ,emailer_for_promotion ,checkout_price,base_price having skewness and they all are positively skeweed
# Out:
# id                      -0.001102
# week                    -0.049517
# center_id                0.345130
# meal_id                 -0.172884
# checkout_price           0.672330
# base_price               0.637661
# emailer_for_promotion    3.067713
# homepage_featured        2.506022
# num_orders               6.929966
# city_code               -0.209131
# region_code              0.056254
# op_area                  0.664414
# dtype: float64

# %%
plt.figure(figsize=(20,15))
num_col
t = 1
for i in num_col:
    if i != 'num_orders':
        plt.subplot(4,3,t)
        sns.boxplot(df_f[i])
        t+=1
plt.show()

# base_price , op_area , checkout_price all are having outliers

# ● We have seen few outlier in the checkout_price , op_area & base_price .
# ● Num_orders is the target variable. It has many outlier .

# %%
plt.figure(figsize=(20,15))
cat_col
t = 1
for i in cat_col:
    plt.subplot(4,3,t)
    sns.countplot(df_f[i])
    t+=1
    plt.xticks(rotation = 60)
plt.show()

# 1. Beverages and Rice Bowl are the food category which has the
# highest number of orders and Soup and Fish are the food
# category with least number of orders.
# 2. In specific Cuisine-Food Category has the highest number of
# orders.In that Food Category we could see that Indian-Rice Bowl
# has the highest number of orders and Indian-Biriyani has the least
# no of orders.

# 1. Italian is the Most Ordered Cuisine, followed by Thai and Indian.
# 2. Type_A Centers are catering to most of the Orders, while Type_B center deals
# with the Lowest no. of orders.

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=(20,15))
t = 1
for i in num_col:
    if i!= 'num_orders':
        plt.subplot(4,4,t)
        sns.scatterplot(df_f[i],df_f['num_orders'])
        t+=1
    
plt.show()


# 1. Most of the Orders have Checkout_Price in range from 100 to 300. It shows that
# there are less bulk orders.
# 2. Most of the Orders have Base Price less than 500. It shows customers are ordering
# for 1 or 2 people only at once.

# %%
sns.scatterplot(y = df_f['num_orders'],x = df_f['base_price'])
# Out:
# <AxesSubplot:xlabel='base_price', ylabel='num_orders'>

# %%
plt.figure(figsize=(20,15))
t = 1
for i in cat_col:
    if i!= 'num_orders':
        plt.subplot(4,4,t)
    sns.boxplot(df_f[i],df_f['num_orders'])
    t+=1
    plt.xticks(rotation = 90)
    
plt.show()

## it shows that their are many outlier and many different category in the city_code cusine , and region_code

# %%
df_f.skew()

# checkout_price , base_price , emailer_for_promotion , homepage_featured has highly skeweed
# Out:
# id                      -0.001102
# week                    -0.049517
# center_id                0.345130
# meal_id                 -0.172884
# checkout_price           0.672330
# base_price               0.637661
# emailer_for_promotion    3.067713
# homepage_featured        2.506022
# num_orders               6.929966
# city_code               -0.209131
# region_code              0.056254
# op_area                  0.664414
# dtype: float64

# %% [markdown]
# ## Multivariate analysis

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df_f.corr() , cmap="YlGnBu", annot=True)

# ● The correlation between the variable with each order is very low so we believe that the
# multicollinearity is also low in them.
# ● But base_price & checkout_price shows high correlation.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %%
df_f.sort_values('city_code',ascending=False).tail()
# Out:
#              id  week center_id  meal_id  checkout_price  base_price  \
# 348776  1071333   116        59     2640          292.03      292.03
# 348775  1182778   115        59     2640          292.03      292.03
# 348774  1291053   114        59     2640          292.03      291.03
# 348773  1365727   113        59     2640          291.03      290.03
# 353257  1097490   145        59     2956          640.23      640.23
#
#        emailer_for_promotion homepage_featured  num_orders  category  \
# 348776                     0                 1         244  Starters
# 348775                     0                 0         325  Starters
# 348774                     0                 1         188  Starters
# 348773                     0                 0         203  Starters
# 353257                     0                 0          53      Fish
#
#             cuisine city_code region_code center_type  op_area
# 348776         Thai       456          56      TYPE_A      4.2
# 348775         Thai       456          56      TYPE_A      4.2
# 348774         Thai       456          56      TYPE_A      4.2
# 348773         Thai       456          56      TYPE_A      4.2
# 353257  Continental       456          56      TYPE_A      4.2

# %%
df_f.num_orders.value_counts()
# Out:
# 13       12397
# 15       12294
# 14       12270
# 28       11548
# 27       11462
# 26       11457
# 41       10344
# 40       10179
# 42       10083
# 54        8845
# 53        8715
# 55        8591
# 68        7650
# 67        7589
# 69        7565
# 80        6722
# 81        6683
# 82        6599
# 95        5961
# 94        5855
# 96        5794
# 107       5315
# 108       5230
# 109       5107
# 122       4792
# 121       4760
# 123       4661
# 134       4307
# 136       4248
# 135       4231
# 148       4113
# 149       4104
# 150       3928
# 163       3839
# 161       3721
# 162       3718
# 177       3584
# 175       3468
# 176       3430
# 190       3347
# 188       3216
# 189       3201
# 204       3065
# 202       3059
# 203       3039
# 216       2874
# 217       2856
# 215       2819
# 231       2704
# 229       2678
# 230       2596
# 242       2527
# 244       2481
# 243       2437
# 257       2412
# 256       2333
# 258       2323
# 270       2243
# 269       2243
# 271       2241
# 284       2161
# 283       2152
# 285       2134
# 297       2054
# 298       2051
# 296       2024
# 311       1918
# 310       1893
# 312       1885
# 325       1817
# 324       1809
# 323       1747
# 339       1722
# 337       1719
# 338       1704
# 351       1664
# 350       1655
# 364       1601
# 352       1590
# 365       1511
# 379       1506
# 378       1482
# 377       1471
# 366       1459
# 392       1386
# 391       1380
# 393       1346
# 405       1302
# 419       1268
# 420       1267
# 406       1260
# 418       1235
# 404       1229
# 433       1202
# 432       1197
# 431       1140
# 446       1133
# 460       1062
# 445       1048
# 447       1039
# 474       1018
# 458       1016
# 472       1006
# 473        986
# 485        977
# 486        961
# 459        955
# 487        952
# 499        891
# 501        879
# 500        873
# 512        830
# 513        814
# 527        794
# 514        791
# 541        771
# 528        769
# 526        768
# 539        748
# 540        730
# 553        716
# 555        710
# 567        703
# 568        698
# 554        694
# 566        675
# 607        635
# 581        625
# 582        618
# 595        612
# 609        608
# 593        598
# 580        596
# 594        584
# 621        564
# 620        563
# 622        559
# 608        558
# 636        554
# 634        553
# 648        538
# 649        527
# 635        523
# 662        509
# 647        506
# 663        501
# 688        496
# 676        482
# 675        480
# 661        479
# 690        462
# 689        457
# 674        449
# 715        438
# 701        430
# 717        408
# 716        400
# 703        392
# 730        392
# 702        384
# 744        365
# 729        364
# 742        364
# 743        362
# 728        358
# 756        356
# 769        355
# 757        353
# 755        352
# 770        347
# 783        347
# 771        340
# 782        321
# 811        320
# 797        320
# 809        317
# 796        310
# 810        304
# 798        304
# 837        297
# 784        294
# 836        293
# 825        291
# 823        290
# 838        281
# 852        279
# 865        278
# 851        270
# 850        256
# 864        256
# 877        253
# 824        253
# 890        251
# 879        250
# 892        235
# 878        229
# 863        226
# 944        222
# 906        219
# 904        217
# 918        216
# 917        214
# 932        212
# 958        207
# 919        206
# 905        203
# 959        198
# 891        198
# 973        198
# 971        197
# 931        194
# 998        192
# 945        190
# 1014       182
# 933        182
# 972        180
# 960        179
# 946        178
# 987        170
# 986        168
# 1012       163
# 1000       163
# 1052       159
# 1013       158
# 985        155
# 1026       152
# 1027       151
# 1066       148
# 1053       148
# 1025       146
# 1068       146
# 1094       145
# 1039       145
# 999        141
# 1067       140
# 1106       138
# 1079       136
# 1041       134
# 1054       133
# 1081       133
# 1149       131
# 1133       131
# 1093       129
# 1121       128
# 1040       127
# 1095       127
# 1134       123
# 1120       120
# 1161       119
# 1187       116
# 1148       115
# 1080       114
# 1135       113
# 1147       112
# 1108       112
# 1189       111
# 1122       107
# 1160       107
# 1107       107
# 1174       105
# 1214       103
# 1201       103
# 1162       101
# 1188        97
# 1176        97
# 1270        95
# 1175        95
# 1216        94
# 1202        93
# 1229        92
# 1297        91
# 1230        90
# 1203        89
# 1241        88
# 1269        86
# 1311        85
# 1243        84
# 1336        83
# 1268        83
# 1257        82
# 1242        82
# 1228        82
# 1284        82
# 1255        80
# 1215        77
# 1351        77
# 1256        76
# 1430        75
# 1323        75
# 1283        75
# 1403        74
# 1324        74
# 1295        73
# 1337        72
# 1378        72
# 1282        72
# 1363        72
# 1417        70
# 1309        70
# 1349        68
# 1365        67
# 1322        66
# 1390        66
# 1473        65
# 1338        64
# 1350        63
# 1446        63
# 1296        62
# 1419        61
# 1391        60
# 1540        60
# 1404        60
# 1377        59
# 1499        59
# 1457        57
# 1431        57
# 1418        57
# 1459        57
# 1444        57
# 1310        56
# 1392        56
# 1472        56
# 1498        56
# 1364        55
# 1405        54
# 1552        53
# 1376        53
# 1458        53
# 1688        51
# 1620        51
# 1486        51
# 1554        50
# 1594        49
# 1525        49
# 1471        48
# 1511        48
# 1621        48
# 1539        47
# 1432        46
# 1592        46
# 1485        46
# 1566        46
# 1687        45
# 1513        45
# 1445        45
# 1608        44
# 1580        44
# 1619        43
# 1526        43
# 1715        43
# 1512        43
# 1553        42
# 1527        41
# 1648        41
# 1701        41
# 1500        41
# 1824        40
# 1635        40
# 1662        40
# 1565        40
# 1634        40
# 1689        39
# 1646        39
# 1647        39
# 1716        39
# 1741        38
# 1593        38
# 1808        37
# 1729        37
# 1484        37
# 1579        37
# 1702        37
# 1633        37
# 1674        36
# 1810        35
# 1769        34
# 1661        34
# 1567        34
# 1754        33
# 1700        33
# 1606        33
# 2011        33
# 1782        33
# 1916        33
# 1538        33
# 1660        33
# 1984        32
# 1756        32
# 1607        32
# 1796        32
# 1905        32
# 1727        31
# 1863        31
# 1581        31
# 1890        31
# 1781        31
# 1770        31
# 1837        31
# 1851        31
# 1675        30
# 1743        30
# 1768        30
# 2012        30
# 1742        30
# 1917        29
# 1755        29
# 1849        29
# 1878        29
# 1930        28
# 1959        28
# 1877        28
# 2039        27
# 1835        27
# 2094        26
# 1850        26
# 1822        26
# 1795        26
# 1797        26
# 1876        26
# 1998        26
# 1889        25
# 1997        25
# 1864        25
# 1823        25
# 1971        25
# 1673        24
# 1957        24
# 1986        24
# 1714        23
# 2051        23
# 1972        23
# 2364        23
# 1836        23
# 1932        23
# 1945        23
# 1958        22
# 2105        22
# 2148        22
# 1944        21
# 1918        20
# 1999        20
# 2107        20
# 1783        20
# 2538        20
# 1970        20
# 2187        20
# 2078        20
# 1728        20
# 2052        19
# 2025        19
# 2093        19
# 1904        19
# 1891        19
# 2079        19
# 2024        18
# 2308        18
# 2283        18
# 2119        17
# 2147        17
# 2213        17
# 2013        17
# 2092        17
# 1809        17
# 1943        17
# 2120        17
# 2080        17
# 2174        17
# 1985        17
# 1903        16
# 2038        16
# 2067        16
# 2186        16
# 2429        16
# 2133        16
# 2026        16
# 2134        15
# 2335        15
# 2066        15
# 1931        15
# 2161        15
# 2121        15
# 2321        15
# 2445        15
# 2296        15
# 2310        15
# 2065        15
# 1862        14
# 2282        14
# 2254        14
# 2484        14
# 2363        14
# 2146        14
# 2404        14
# 2295        13
# 2418        13
# 2227        13
# 2294        13
# 2403        13
# 2511        13
# 2053        13
# 2267        13
# 2159        13
# 2377        13
# 2471        13
# 2444        13
# 2229        13
# 2269        13
# 2160        12
# 2201        12
# 2323        12
# 2580        12
# 2591        12
# 2376        12
# 2470        12
# 2132        12
# 2605        12
# 2175        12
# 2106        12
# 2417        11
# 2202        11
# 2566        11
# 2240        11
# 2200        11
# 2389        11
# 2537        11
# 2256        11
# 2391        11
# 2214        11
# 2348        11
# 2228        11
# 2606        11
# 2255        11
# 2430        11
# 2564        10
# 2309        10
# 2848        10
# 2375        10
# 2173        10
# 2443        10
# 2754        10
# 2645        10
# 2242        10
# 2620        10
# 2835        10
# 2457        10
# 2040        10
# 2268        10
# 2660        10
# 2241        10
# 2524        10
# 2281        10
# 2188        10
# 3174         9
# 2458         9
# 2915         9
# 2483         9
# 2349         9
# 2485         9
# 2553         9
# 2362         9
# 2688         9
# 2402         9
# 2674         9
# 2998         9
# 2822         8
# 2877         8
# 2890         8
# 2526         8
# 2942         8
# 2472         8
# 2552         8
# 2215         8
# 3389         8
# 2983         8
# 2753         8
# 2539         8
# 2510         8
# 2498         8
# 2861         8
# 2647         8
# 2456         8
# 2714         8
# 2740         8
# 2970         8
# 2416         8
# 3119         8
# 2337         8
# 2618         8
# 2646         8
# 3280         7
# 2985         7
# 2687         7
# 2659         7
# 2607         7
# 3012         7
# 3266         7
# 2876         7
# 2672         7
# 2592         7
# 3160         7
# 2902         7
# 3402         7
# 2499         7
# 2551         7
# 2431         7
# 2322         7
# 2525         7
# 3172         7
# 3605         7
# 2390         7
# 2836         7
# 2701         7
# 2700         7
# 2497         7
# 2916         7
# 3455         6
# 2931         6
# 3739         6
# 2997         6
# 3644         6
# 2619         6
# 3523         6
# 2782         6
# 3482         6
# 2888         6
# 2727         6
# 2809         6
# 2742         6
# 3039         6
# 2794         6
# 3145         6
# 3147         6
# 2661         6
# 2780         6
# 3118         6
# 3051         6
# 2336         6
# 3295         6
# 2593         6
# 2929         6
# 2713         6
# 2862         6
# 2823         6
# 2957         6
# 2849         6
# 2512         6
# 2634         6
# 2768         6
# 2781         6
# 2904         5
# 3065         5
# 2632         5
# 3052         5
# 2850         5
# 2834         5
# 3010         5
# 3511         5
# 2728         5
# 3471         5
# 2969         5
# 3740         5
# 3066         5
# 3551         5
# 3376         5
# 2755         5
# 2699         5
# 2686         5
# 2565         5
# 3214         5
# 2807         5
# 2578         5
# 2889         5
# 2808         5
# 3050         5
# 2984         5
# 3309         5
# 3104         5
# 2633         5
# 2956         5
# 2715         5
# 4227         5
# 3753         5
# 2795         5
# 2903         5
# 2875         5
# 2741         4
# 3712         4
# 3293         4
# 3403         4
# 2930         4
# 3106         4
# 3457         4
# 3281         4
# 3120         4
# 3079         4
# 3969         4
# 3159         4
# 4254         4
# 3093         4
# 3241         4
# 3158         4
# 3320         4
# 3335         4
# 3888         4
# 3133         4
# 2673         4
# 3646         4
# 3038         4
# 3308         4
# 2996         4
# 4051         4
# 3984         4
# 3578         4
# 2579         4
# 3199         4
# 3146         4
# 3131         4
# 3687         4
# 3388         4
# 2943         4
# 3200         4
# 3606         4
# 2767         4
# 3011         4
# 3132         4
# 3336         4
# 3807         4
# 2796         4
# 4036         4
# 4011         4
# 3552         4
# 3565         4
# 3228         4
# 4414         3
# 3390         3
# 3362         3
# 4604         3
# 3835         3
# 3091         3
# 3347         3
# 3226         3
# 2944         3
# 3334         3
# 4699         3
# 4010         3
# 3430         3
# 3618         3
# 3875         3
# 5075         3
# 3577         3
# 2863         3
# 4238         3
# 3374         3
# 3700         3
# 2769         3
# 3268         3
# 3874         3
# 4441         3
# 3970         3
# 5143         3
# 4726         3
# 3282         3
# 3442         3
# 3901         3
# 4427         3
# 2917         3
# 3876         3
# 2726         3
# 3456         3
# 3538         3
# 2350         3
# 3752         3
# 3375         3
# 5145         3
# 3983         3
# 3105         3
# 3348         3
# 3470         3
# 3714         3
# 3592         3
# 3699         3
# 3780         3
# 3930         3
# 4077         3
# 4037         3
# 3794         3
# 3417         3
# 3847         3
# 5820         3
# 3253         3
# 3996         3
# 3322         3
# 4672         3
# 4887         3
# 2821         3
# 3806         3
# 3550         3
# 3821         3
# 3496         3
# 3185         2
# 3808         2
# 4806         2
# 4171         2
# 5495         2
# 3416         2
# 5280         2
# 3536         2
# 4550         2
# 4225         2
# 4226         2
# 4132         2
# 3037         2
# 6575         2
# 4159         2
# 4267         2
# 3497         2
# 3795         2
# 4063         2
# 5334         2
# 6103         2
# 3444         2
# 6117         2
# 3848         2
# 5264         2
# 4834         2
# 5157         2
# 4281         2
# 6426         2
# 4832         2
# 5279         2
# 6171         2
# 5440         2
# 3525         2
# 4145         2
# 4576         2
# 4292         2
# 3239         2
# 4157         2
# 4402         2
# 3023         2
# 5994         2
# 3617         2
# 3968         2
# 3024         2
# 3698         2
# 4522         2
# 3254         2
# 4711         2
# 4983         2
# 5577         2
# 8140         2
# 3401         2
# 4429         2
# 3822         2
# 5090         2
# 4388         2
# 5658         2
# 5697         2
# 3443         2
# 3429         2
# 3889         2
# 5899         2
# 3833         2
# 5454         2
# 4200         2
# 3685         2
# 4252         2
# 4861         2
# 3943         2
# 6481         2
# 4319         2
# 4173         2
# 3887         2
# 3659         2
# 3672         2
# 6615         2
# 3633         2
# 3713         2
# 4184         2
# 4509         2
# 3997         2
# 7263         2
# 3727         2
# 3201         2
# 4065         2
# 4820         2
# 4630         2
# 3509         2
# 3186         2
# 7601         2
# 8518         2
# 4712         2
# 6479         2
# 3726         2
# 4589         2
# 3428         2
# 3025         2
# 4049         2
# 3673         2
# 2971         2
# 4293         2
# 2958         2
# 4117         2
# 5507         2
# 4549         2
# 3524         2
# 3255         2
# 4104         2
# 4280         2
# 3928         2
# 3619         2
# 4320         2
# 4307         2
# 4536         2
# 4334         2
# 3862         2
# 4347         2
# 5050         2
# 7722         2
# 3321         2
# 3929         2
# 3564         2
# 3363         2
# 4739         2
# 4603         2
# 4766         2
# 6695         2
# 5941         2
# 4321         2
# 7088         2
# 5737         2
# 3982         2
# 3767         2
# 5022         1
# 4631         1
# 7694         1
# 3227         1
# 4955         1
# 3213         1
# 7021         1
# 5874         1
# 3510         1
# 4941         1
# 4294         1
# 6467         1
# 4873         1
# 3957         1
# 6468         1
# 9044         1
# 13580        1
# 4751         1
# 6466         1
# 4022         1
# 9532         1
# 6333         1
# 5063         1
# 4551         1
# 5036         1
# 6197         1
# 5967         1
# 4618         1
# 3212         1
# 7749         1
# 6304         1
# 3483         1
# 4239         1
# 4914         1
# 6750         1
# 6589         1
# 10745        1
# 3469         1
# 3955         1
# 7803         1
# 4902         1
# 6372         1
# 9019         1
# 6047         1
# 4940         1
# 4253         1
# 6601         1
# 5739         1
# 9828         1
# 4050         1
# 9249         1
# 7829         1
# 5804         1
# 5955         1
# 4793         1
# 3173         1
# 4780         1
# 4090         1
# 4765         1
# 4969         1
# 4131         1
# 5278         1
# 6182         1
# 7060         1
# 4400         1
# 6804         1
# 3631         1
# 3860         1
# 6967         1
# 4632         1
# 5386         1
# 5845         1
# 4994         1
# 5307         1
# 6048         1
# 3766         1
# 3267         1
# 7898         1
# 8059         1
# 3686         1
# 3861         1
# 8169         1
# 13150        1
# 7708         1
# 6076         1
# 6777         1
# 9773         1
# 3307         1
# 5360         1
# 3632         1
# 4697         1
# 6344         1
# 4643         1
# 8774         1
# 6035         1
# 10449        1
# 7073         1
# 8762         1
# 4172         1
# 4859         1
# 4374         1
# 3671         1
# 8612         1
# 3849         1
# 8288         1
# 7114         1
# 7141         1
# 8222         1
# 4685         1
# 3793         1
# 6844         1
# 5590         1
# 4779         1
# 15336        1
# 14229        1
# 24299        1
# 5629         1
# 3914         1
# 4767         1
# 8520         1
# 6480         1
# 4807         1
# 3902         1
# 4442         1
# 3092         1
# 8897         1
# 5103         1
# 3781         1
# 7075         1
# 6790         1
# 4023         1
# 7804         1
# 8830         1
# 6751         1
# 6290         1
# 11110        1
# 9220         1
# 10140        1
# 5428         1
# 7965         1
# 5010         1
# 8736         1
# 5778         1
# 4967         1
# 3820         1
# 9855         1
# 3349         1
# 4212         1
# 4645         1
# 4819         1
# 4535         1
# 6629         1
# 7168         1
# 5616         1
# 5548         1
# 4373         1
# 7667         1
# 8034         1
# 8492         1
# 8884         1
# 8585         1
# 12177        1
# 3956         1
# 3660         1
# 3834         1
# 5671         1
# 3077         1
# 3361         1
# 6562         1
# 4470         1
# 4929         1
# 4186         1
# 12489        1
# 3294         1
# 7062         1
# 4591         1
# 5588         1
# 7926         1
# 11056        1
# 3590         1
# 5224         1
# 4778         1
# 4495         1
# 6657         1
# 5873         1
# 3995         1
# 6252         1
# 12327        1
# 8911         1
# 6358         1
# 4455         1
# 5401         1
# 4361         1
# 5399         1
# 4076         1
# 4118         1
# 6359         1
# 10193        1
# 9815         1
# 12137        1
# 3658         1
# 4847         1
# 5535         1
# 10259        1
# 4105         1
# 4103         1
# 6142         1
# 4605         1
# 5914         1
# 5265         1
# 6859         1
# 7262         1
# 4508         1
# 4913         1
# 7155         1
# 5561         1
# 5305         1
# 6643         1
# 3415         1
# 5563         1
# 4468         1
# 5427         1
# 11260        1
# 4428         1
# 3484         1
# 4064         1
# 4577         1
# 5912         1
# 5252         1
# 3768         1
# 5129         1
# 5102         1
# 4821         1
# 4564         1
# 6655         1
# 6912         1
# 9114         1
# 5037         1
# 4524         1
# 7872         1
# 3754         1
# 4389         1
# 4901         1
# 5130         1
# 4968         1
# 3604         1
# 5170         1
# 3187         1
# 5631         1
# 4454         1
# 3779         1
# 5373         1
# 4443         1
# 5413         1
# 11246        1
# 4954         1
# 5630         1
# 5604         1
# 10124        1
# 5361         1
# 4416         1
# 5818         1
# 3916         1
# 3942         1
# 7911         1
# 4671         1
# 4590         1
# 6129         1
# 6533         1
# 5400         1
# 5792         1
# 5509         1
# 7559         1
# 5480         1
# 10544        1
# 4362         1
# 4483         1
# 7007         1
# 9045         1
# 10435        1
# 4146         1
# 5521         1
# 5158         1
# 6927         1
# 4848         1
# 6441         1
# 5550         1
# 6884         1
# 6210         1
# 4130         1
# 5860         1
# 11380        1
# 4725         1
# 3903         1
# 4670         1
# 5657         1
# 5669         1
# 3064         1
# 4009         1
# 5318         1
# 5698         1
# 5576         1
# 6576         1
# 6062         1
# 9303         1
# 7602         1
# 6507         1
# 4306         1
# 3645         1
# 8979         1
# 4684         1
# 7399         1
# 6697         1
# 7008         1
# 7127         1
# 4185         1
# 3078         1
# Name: num_orders, dtype: int64

# %%
df_f
# Out:
#              id  week center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1        55     1885          136.83      152.29
# 1       1018704     2        55     1885          135.83      152.29
# 2       1196273     3        55     1885          132.92      133.92
# 3       1116527     4        55     1885          135.86      134.86
# 4       1343872     5        55     1885          146.50      147.50
# ...         ...   ...       ...      ...             ...         ...
# 456543  1437396   141        61     2104          583.03      630.53
# 456544  1060716   142        61     2104          581.03      582.03
# 456545  1029231   143        61     2104          583.03      581.03
# 456546  1141147   144        61     2104          582.03      581.03
# 456547  1443704   145        61     2104          581.03      582.03
#
#        emailer_for_promotion homepage_featured  num_orders   category  \
# 0                          0                 0         177  Beverages
# 1                          0                 0         323  Beverages
# 2                          0                 0          96  Beverages
# 3                          0                 0         163  Beverages
# 4                          0                 0         215  Beverages
# ...                      ...               ...         ...        ...
# 456543                     0                 1          13       Fish
# 456544                     0                 0          42       Fish
# 456545                     0                 0          40       Fish
# 456546                     0                 0          53       Fish
# 456547                     0                 0          27       Fish
#
#             cuisine city_code region_code center_type  op_area
# 0              Thai       647          56      TYPE_C      2.0
# 1              Thai       647          56      TYPE_C      2.0
# 2              Thai       647          56      TYPE_C      2.0
# 3              Thai       647          56      TYPE_C      2.0
# 4              Thai       647          56      TYPE_C      2.0
# ...             ...       ...         ...         ...      ...
# 456543  Continental       473          77      TYPE_A      4.5
# 456544  Continental       473          77      TYPE_A      4.5
# 456545  Continental       473          77      TYPE_A      4.5
# 456546  Continental       473          77      TYPE_A      4.5
# 456547  Continental       473          77      TYPE_A      4.5
#
# [456548 rows x 15 columns]

# %%
df_f[df_f['checkout_price']<df_f['base_price']]
# Out:
#              id  week center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1        55     1885          136.83      152.29
# 1       1018704     2        55     1885          135.83      152.29
# 2       1196273     3        55     1885          132.92      133.92
# 4       1343872     5        55     1885          146.50      147.50
# 6       1110832     7        55     1885          145.53      146.53
# ...         ...   ...       ...      ...             ...         ...
# 456541  1314947   139        61     2104          490.82      629.53
# 456542  1020517   140        61     2104          485.03      629.53
# 456543  1437396   141        61     2104          583.03      630.53
# 456544  1060716   142        61     2104          581.03      582.03
# 456547  1443704   145        61     2104          581.03      582.03
#
#        emailer_for_promotion homepage_featured  num_orders   category  \
# 0                          0                 0         177  Beverages
# 1                          0                 0         323  Beverages
# 2                          0                 0          96  Beverages
# 4                          0                 0         215  Beverages
# 6                          0                 0         148  Beverages
# ...                      ...               ...         ...        ...
# 456541                     0                 1         312       Fish
# 456542                     0                 1         149       Fish
# 456543                     0                 1          13       Fish
# 456544                     0                 0          42       Fish
# 456547                     0                 0          27       Fish
#
#             cuisine city_code region_code center_type  op_area
# 0              Thai       647          56      TYPE_C      2.0
# 1              Thai       647          56      TYPE_C      2.0
# 2              Thai       647          56      TYPE_C      2.0
# 4              Thai       647          56      TYPE_C      2.0
# 6              Thai       647          56      TYPE_C      2.0
# ...             ...       ...         ...         ...      ...
# 456541  Continental       473          77      TYPE_A      4.5
# 456542  Continental       473          77      TYPE_A      4.5
# 456543  Continental       473          77      TYPE_A      4.5
# 456544  Continental       473          77      TYPE_A      4.5
# 456547  Continental       473          77      TYPE_A      4.5
#
# [229687 rows x 15 columns]

# %%
df_f['discount']=np.where(df_f.checkout_price<df_f.base_price,'Yes','No')  # create a new feature discount in the dataset

# %%
sns.countplot(df_f.discount)

# 1. The Number of Orders having
# Discounted Products and not
# having Discounted Products is
# almost the same.
# 1. This Shows present Discount
# Scheme is not working.
# Out:
# <AxesSubplot:xlabel='discount', ylabel='count'>

# %%
df_f.groupby('center_type')['num_orders'].describe()
# Out:
#                 count        mean         std   min   25%    50%    75%  \
# center_type
# TYPE_A       262881.0  262.394456  401.513549  13.0  54.0  136.0  324.0
# TYPE_B        94074.0  318.856145  436.773777  13.0  69.0  176.0  392.0
# TYPE_C        99593.0  206.670097  326.716100  13.0  40.0  107.0  258.0
#
#                  max
# center_type
# TYPE_A       24299.0
# TYPE_B       13580.0
# TYPE_C       10124.0

# %%
df_f.groupby('center_type')['region_code'].describe()
# Out:
#               count  unique  top    freq
# center_type
# TYPE_A       262881       8   56  112218
# TYPE_B        94074       4   56   41588
# TYPE_C        99593       4   56   37422

# %%
df_f.region_code.nunique()
# Out:
# 8

# %%
df_f
# Out:
#              id  week center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1        55     1885          136.83      152.29
# 1       1018704     2        55     1885          135.83      152.29
# 2       1196273     3        55     1885          132.92      133.92
# 3       1116527     4        55     1885          135.86      134.86
# 4       1343872     5        55     1885          146.50      147.50
# ...         ...   ...       ...      ...             ...         ...
# 456543  1437396   141        61     2104          583.03      630.53
# 456544  1060716   142        61     2104          581.03      582.03
# 456545  1029231   143        61     2104          583.03      581.03
# 456546  1141147   144        61     2104          582.03      581.03
# 456547  1443704   145        61     2104          581.03      582.03
#
#        emailer_for_promotion homepage_featured  num_orders   category  \
# 0                          0                 0         177  Beverages
# 1                          0                 0         323  Beverages
# 2                          0                 0          96  Beverages
# 3                          0                 0         163  Beverages
# 4                          0                 0         215  Beverages
# ...                      ...               ...         ...        ...
# 456543                     0                 1          13       Fish
# 456544                     0                 0          42       Fish
# 456545                     0                 0          40       Fish
# 456546                     0                 0          53       Fish
# 456547                     0                 0          27       Fish
#
#             cuisine city_code region_code center_type  op_area discount
# 0              Thai       647          56      TYPE_C      2.0      Yes
# 1              Thai       647          56      TYPE_C      2.0      Yes
# 2              Thai       647          56      TYPE_C      2.0      Yes
# 3              Thai       647          56      TYPE_C      2.0       No
# 4              Thai       647          56      TYPE_C      2.0      Yes
# ...             ...       ...         ...         ...      ...      ...
# 456543  Continental       473          77      TYPE_A      4.5      Yes
# 456544  Continental       473          77      TYPE_A      4.5      Yes
# 456545  Continental       473          77      TYPE_A      4.5       No
# 456546  Continental       473          77      TYPE_A      4.5       No
# 456547  Continental       473          77      TYPE_A      4.5      Yes
#
# [456548 rows x 16 columns]

# %%
df_f.discount.describe()
# Out:
# count     456548
# unique         2
# top          Yes
# freq      229687
# Name: discount, dtype: object

# %%
# df_f['difference']=np.where(df_f.checkout_price>df_f.base_price,df_f.checkout_price-df_f.base_price,'0')

# %%
df_f.meal_id.nunique()
# Out:
# 51

# %%
df_f.category.nunique()
# Out:
# 14

# %%
df_f.groupby('category')['checkout_price','base_price'].value_counts().head(10)
# Out:
# category   checkout_price  base_price
# Beverages  153.26          153.26        648
#            154.26          155.26        633
#                            154.26        621
#                            153.26        620
#            155.26          153.26        618
#            153.26          154.26        611
#            155.26          155.26        595
#                            154.26        592
#            153.26          155.26        561
#            290.03          292.03        271
# dtype: int64

# %%
df_f.head()
# Out:
#         id  week center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1        55     1885          136.83      152.29
# 1  1018704     2        55     1885          135.83      152.29
# 2  1196273     3        55     1885          132.92      133.92
# 3  1116527     4        55     1885          135.86      134.86
# 4  1343872     5        55     1885          146.50      147.50
#
#   emailer_for_promotion homepage_featured  num_orders   category cuisine  \
# 0                     0                 0         177  Beverages    Thai
# 1                     0                 0         323  Beverages    Thai
# 2                     0                 0          96  Beverages    Thai
# 3                     0                 0         163  Beverages    Thai
# 4                     0                 0         215  Beverages    Thai
#
#   city_code region_code center_type  op_area discount difference
# 0       647          56      TYPE_C      2.0      Yes          0
# 1       647          56      TYPE_C      2.0      Yes          0
# 2       647          56      TYPE_C      2.0      Yes          0
# 3       647          56      TYPE_C      2.0       No        1.0
# 4       647          56      TYPE_C      2.0      Yes          0

# %%
df_f.groupby(['center_type','region_code','city_code'])['cuisine','op_area','checkout_price','base_price','discount'].value_counts().head(10)
# Out:
# center_type  region_code  city_code  cuisine  op_area  checkout_price  base_price  discount
# TYPE_A       23           698        Thai     3.4      290.03          292.03      Yes         41
#                                                                        290.03      No          40
#                                                                        291.03      Yes         37
#                                                        292.03          292.03      No          37
#                                                        291.03          291.03      No          36
#                                                                        292.03      Yes         36
#                                                        292.03          291.03      No          31
#                                      Indian   3.4      446.23          447.23      Yes         28
#                                                        447.23          446.23      No          28
#                                                                        447.23      No          26
# dtype: int64

# %%
df_f.groupby(['center_type','cuisine'])['category'].value_counts().head(100)
# Out:
# center_type  cuisine      category
# TYPE_A       Continental  Pizza           18575
#                           Beverages       18391
#                           Seafood         15946
#                           Fish             6302
#              Indian       Rice Bowl       18705
#                           Beverages       17097
#                           Desert          16754
#                           Biryani         12414
#              Italian      Beverages       18700
#                           Sandwich        18681
#                           Pasta           16052
#                           Salad           16038
#              Thai         Beverages       18474
#                           Starters        17716
#                           Other Snacks    17360
#                           Extras           8050
#                           Soup             7626
# TYPE_B       Continental  Pizza            6425
#                           Beverages        6280
#                           Seafood          6072
#                           Fish             2871
#              Indian       Rice Bowl        6450
#                           Desert           5979
#                           Beverages        5793
#                           Biryani          5306
#              Italian      Beverages        6447
#                           Sandwich         6435
#                           Pasta            5892
#                           Salad            5574
#              Thai         Starters         6409
#                           Beverages        6270
#                           Other Snacks     6181
#                           Soup             2863
#                           Extras           2827
# TYPE_C       Continental  Pizza            8138
#                           Beverages        7883
#                           Seafood          4898
#                           Fish             1014
#              Indian       Rice Bowl        8253
#                           Desert           6561
#                           Beverages        6406
#                           Biryani          2894
#              Italian      Beverages        8234
#                           Sandwich         8175
#                           Salad            6947
#                           Pasta            5750
#              Thai         Beverages        7915
#                           Other Snacks     5838
#                           Starters         5816
#                           Extras           2685
#                           Soup             2186
# Name: category, dtype: int64

# %%
df_f.city_code.unique()
# Out:
# array([647, 614, 679, 659, 526, 590, 599, 685, 461, 649, 541, 478, 703,
#        576, 628, 702, 579, 596, 648, 632, 522, 615, 577, 517, 651, 683,
#        713, 609, 675, 553, 593, 654, 693, 658, 515, 556, 561, 680, 620,
#        638, 700, 676, 604, 456, 562, 695, 699, 602, 485, 698, 473],
#       dtype=object)

# %%
df_f.groupby(['category','cuisine'])['checkout_price'].value_counts().head(10)
# Out:
# category   cuisine      checkout_price
# Beverages  Continental  325.98            813
#                         323.98            795
#                         324.98            793
#                         388.00            673
#                         390.00            663
#                         389.00            650
#                         321.10            444
#                         324.01            427
#                         322.10            420
#                         323.01            413
# Name: checkout_price, dtype: int64

# %%
df_f.category.nunique()
# Out:
# 14

# %%
df_f.groupby(['category','cuisine'])['checkout_price','base_price','discount'].value_counts().head()
# Out:
# category   cuisine      checkout_price  base_price  discount
# Beverages  Continental  325.98          324.98      No          241
#                                         323.98      No          240
#                         323.98          323.98      No          238
#                         324.98          325.98      Yes         228
#                                         324.98      No          228
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.countplot(df_f['category'])
plt.ylabel('T otal No of orders')
# Out:
# Text(0, 0.5, 'T otal No of orders')

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456548 entries, 0 to 456547
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     456548 non-null  int64
#  1   week                   456548 non-null  int64
#  2   center_id              456548 non-null  object
#  3   meal_id                456548 non-null  int64
#  4   checkout_price         456548 non-null  float64
#  5   base_price             456548 non-null  float64
#  6   emailer_for_promotion  456548 non-null  object
#  7   homepage_featured      456548 non-null  object
#  8   num_orders             456548 non-null  int64
#  9   category               456548 non-null  object
#  10  cuisine                456548 non-null  object
#  11  city_code              456548 non-null  object
#  12  region_code            456548 non-null  object
#  13  center_type            456548 non-null  object
#  14  op_area                456548 non-null  float64
#  15  discount               456548 non-null  object
#  16  difference             456548 non-null  object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 62.7+ MB

# %%
df_f.isnull().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# category                 0
# cuisine                  0
# city_code                0
# region_code              0
# center_type              0
# op_area                  0
# discount                 0
# difference               0
# dtype: int64

# %%
df_f.head(100)
# Out:
#          id  week center_id  meal_id  checkout_price  base_price  \
# 0   1379560     1        55     1885          136.83      152.29
# 1   1018704     2        55     1885          135.83      152.29
# 2   1196273     3        55     1885          132.92      133.92
# 3   1116527     4        55     1885          135.86      134.86
# 4   1343872     5        55     1885          146.50      147.50
# 5   1493612     6        55     1885          146.53      146.53
# 6   1110832     7        55     1885          145.53      146.53
# 7   1461167     8        55     1885          146.53      145.53
# 8   1102364     9        55     1885          134.83      134.83
# 9   1018130    10        55     1885          144.56      143.56
# 10  1047565    11        55     1885          146.53      144.53
# 11  1282497    12        55     1885          145.53      146.53
# 12  1136216    13        55     1885          145.50      146.50
# 13  1196793    14        55     1885          142.62      141.62
# 14  1324644    15        55     1885          117.37      143.62
# 15  1239157    16        55     1885          117.37      141.62
# 16  1056819    17        55     1885          122.28      143.62
# 17  1278127    18        55     1885          120.28      142.62
# 18  1027349    19        55     1885          120.28      143.62
# 19  1466073    20        55     1885          121.28      142.62
# 20  1430267    21        55     1885          120.34      118.34
# 21  1127751    22        55     1885          122.25      123.25
# 22  1256693    23        55     1885          162.05      161.05
# 23  1132283    24        55     1885          165.93      165.93
# 24  1145816    25        55     1885          163.93      165.93
# 25  1035577    26        55     1885          164.96      162.96
# 26  1092191    27        55     1885          121.25      163.96
# 27  1318743    28        55     1885          122.28      162.96
# 28  1389231    29        55     1885          119.31      163.96
# 29  1055602    30        55     1885          122.28      162.96
# 30  1243549    31        55     1885          121.28      164.96
# 31  1410032    32        55     1885          121.28      163.96
# 32  1211414    33        55     1885          123.25      122.25
# 33  1417990    34        55     1885          120.31      121.31
# 34  1257685    35        55     1885          119.34      119.34
# 35  1461594    36        55     1885          121.25      122.25
# 36  1013044    37        55     1885          121.25      123.25
# 37  1447647    38        55     1885          117.43      116.43
# 38  1290788    39        55     1885          144.59      142.59
# 39  1383914    40        55     1885          143.62      141.62
# 40  1192134    41        55     1885          146.53      146.53
# 41  1281925    42        55     1885          144.59      144.59
# 42  1392457    43        55     1885          146.50      146.50
# 43  1318513    44        55     1885          147.50      146.50
# 44  1171536    45        55     1885          146.53      144.53
# 45  1117219    46        55     1885          143.56      144.56
# 46  1216566    47        55     1885          146.53      146.53
# 47  1078055    48        55     1885          122.25      145.53
# 48  1040328    49        55     1885          121.25      144.53
# 49  1089038    50        55     1885          122.28      144.53
# 50  1295163    51        55     1885          121.28      145.53
# 51  1129709    52        55     1885          122.25      144.53
# 52  1494862    53        55     1885          122.28      145.53
# 53  1310682    54        55     1885          122.28      146.53
# 54  1238029    55        55     1885          122.28      146.53
# 55  1265390    56        55     1885          122.22      145.53
# 56  1147031    57        55     1885          144.53      145.53
# 57  1146064    58        55     1885          146.50      145.50
# 58  1391300    59        55     1885          144.53      146.53
# 59  1074454    60        55     1885          141.62      142.62
# 60  1166041    61        55     1885          145.56      143.56
# 61  1060959    62        55     1885          143.59      143.59
# 62  1111544    63        55     1885          140.65      141.65
# 63  1388852    64        55     1885          144.56      145.56
# 64  1230211    65        55     1885          143.56      143.56
# 65  1203610    66        55     1885          142.62      142.62
# 66  1278418    67        55     1885          144.53      146.53
# 67  1005634    68        55     1885          144.56      145.56
# 68  1044232    69        55     1885          146.53      144.53
# 69  1160199    70        55     1885          145.53      146.53
# 70  1006478    71        55     1885          147.50      146.50
# 71  1374081    72        55     1885          143.59      144.59
# 72  1471179    73        55     1885          147.50      147.50
# 73  1233922    74        55     1885          144.56      145.56
# 74  1469475    75        55     1885          143.59      144.59
# 75  1445721    76        55     1885          141.65      141.65
# 76  1333375    77        55     1885          145.56      144.56
# 77  1150374    78        55     1885          146.53      144.53
# 78  1228971    79        55     1885          144.53      145.53
# 79  1008784    80        55     1885          143.56      144.56
# 80  1200384    81        55     1885          146.53      144.53
# 81  1251631    82        55     1885          144.53      146.53
# 82  1326090    83        55     1885          146.53      146.53
# 83  1386980    84        55     1885          141.62      141.62
# 84  1228542    85        55     1885          141.65      142.65
# 85  1085495    86        55     1885          139.74      139.74
# 86  1302683    87        55     1885          144.56      145.56
# 87  1457500    88        55     1885          143.56      143.56
# 88  1084881    89        55     1885          143.62      143.62
# 89  1015503    90        55     1885          144.53      146.53
# 90  1150874    91        55     1885          132.89      134.89
# 91  1456892    92        55     1885          135.86      134.86
# 92  1346470    93        55     1885          130.98      130.98
# 93  1089388    94        55     1885          132.89      134.89
# 94  1320400    95        55     1885          134.86      133.86
# 95  1082385    96        55     1885          136.83      135.83
# 96  1402857    97        55     1885          133.86      135.86
# 97  1131589    98        55     1885          120.28      134.86
# 98  1235173    99        55     1885          146.47      148.47
# 99  1256496   100        55     1885          144.53      146.53
#
#    emailer_for_promotion homepage_featured  num_orders   category cuisine  \
# 0                      0                 0         177  Beverages    Thai
# 1                      0                 0         323  Beverages    Thai
# 2                      0                 0          96  Beverages    Thai
# 3                      0                 0         163  Beverages    Thai
# 4                      0                 0         215  Beverages    Thai
# 5                      0                 0         285  Beverages    Thai
# 6                      0                 0         148  Beverages    Thai
# 7                      0                 0         135  Beverages    Thai
# 8                      0                 0         175  Beverages    Thai
# 9                      0                 0         175  Beverages    Thai
# 10                     0                 0         244  Beverages    Thai
# 11                     0                 0         190  Beverages    Thai
# 12                     0                 0          68  Beverages    Thai
# 13                     0                 0         135  Beverages    Thai
# 14                     0                 0         366  Beverages    Thai
# 15                     0                 0          67  Beverages    Thai
# 16                     0                 0         270  Beverages    Thai
# 17                     0                 0         350  Beverages    Thai
# 18                     0                 0         244  Beverages    Thai
# 19                     0                 0         188  Beverages    Thai
# 20                     0                 0         136  Beverages    Thai
# 21                     0                 0         296  Beverages    Thai
# 22                     0                 0         188  Beverages    Thai
# 23                     0                 0         161  Beverages    Thai
# 24                     0                 0          55  Beverages    Thai
# 25                     0                 0         176  Beverages    Thai
# 26                     0                 0         202  Beverages    Thai
# 27                     0                 0         296  Beverages    Thai
# 28                     0                 0         107  Beverages    Thai
# 29                     0                 0         135  Beverages    Thai
# 30                     0                 0         203  Beverages    Thai
# 31                     0                 0         123  Beverages    Thai
# 32                     0                 0         215  Beverages    Thai
# 33                     0                 0         231  Beverages    Thai
# 34                     0                 0         284  Beverages    Thai
# 35                     0                 0         161  Beverages    Thai
# 36                     0                 0         188  Beverages    Thai
# 37                     0                 0         175  Beverages    Thai
# 38                     0                 0         270  Beverages    Thai
# 39                     0                 0         298  Beverages    Thai
# 40                     0                 0         323  Beverages    Thai
# 41                     0                 0         351  Beverages    Thai
# 42                     0                 0         378  Beverages    Thai
# 43                     0                 0         419  Beverages    Thai
# 44                     0                 0         256  Beverages    Thai
# 45                     0                 0         460  Beverages    Thai
# 46                     0                 0         350  Beverages    Thai
# 47                     0                 0         366  Beverages    Thai
# 48                     0                 1         433  Beverages    Thai
# 49                     0                 1         513  Beverages    Thai
# 50                     0                 1         284  Beverages    Thai
# 51                     1                 1         406  Beverages    Thai
# 52                     1                 1         500  Beverages    Thai
# 53                     0                 1         404  Beverages    Thai
# 54                     0                 1         419  Beverages    Thai
# 55                     0                 1         323  Beverages    Thai
# 56                     0                 1         782  Beverages    Thai
# 57                     0                 0         284  Beverages    Thai
# 58                     0                 0         203  Beverages    Thai
# 59                     0                 0         271  Beverages    Thai
# 60                     0                 0         432  Beverages    Thai
# 61                     0                 0         108  Beverages    Thai
# 62                     0                 0         432  Beverages    Thai
# 63                     0                 0         231  Beverages    Thai
# 64                     0                 0         298  Beverages    Thai
# 65                     0                 0         391  Beverages    Thai
# 66                     0                 0         420  Beverages    Thai
# 67                     0                 0         188  Beverages    Thai
# 68                     0                 0         391  Beverages    Thai
# 69                     0                 0         485  Beverages    Thai
# 70                     0                 0         351  Beverages    Thai
# 71                     0                 0         377  Beverages    Thai
# 72                     0                 0         175  Beverages    Thai
# 73                     0                 0         379  Beverages    Thai
# 74                     0                 0         404  Beverages    Thai
# 75                     0                 0         269  Beverages    Thai
# 76                     0                 0         257  Beverages    Thai
# 77                     0                 0         230  Beverages    Thai
# 78                     0                 0         284  Beverages    Thai
# 79                     0                 0         271  Beverages    Thai
# 80                     0                 0         163  Beverages    Thai
# 81                     0                 0         148  Beverages    Thai
# 82                     0                 0         242  Beverages    Thai
# 83                     0                 0         216  Beverages    Thai
# 84                     0                 0         231  Beverages    Thai
# 85                     0                 0         204  Beverages    Thai
# 86                     0                 0         256  Beverages    Thai
# 87                     0                 0         377  Beverages    Thai
# 88                     0                 0         258  Beverages    Thai
# 89                     0                 0         271  Beverages    Thai
# 90                     0                 0         244  Beverages    Thai
# 91                     0                 0         231  Beverages    Thai
# 92                     0                 0         176  Beverages    Thai
# 93                     0                 0         107  Beverages    Thai
# 94                     0                 0         257  Beverages    Thai
# 95                     0                 0         271  Beverages    Thai
# 96                     0                 0         203  Beverages    Thai
# 97                     0                 0         134  Beverages    Thai
# 98                     0                 0         109  Beverages    Thai
# 99                     0                 0         163  Beverages    Thai
#
#    city_code region_code center_type  op_area discount difference
# 0        647          56      TYPE_C      2.0      Yes          0
# 1        647          56      TYPE_C      2.0      Yes          0
# 2        647          56      TYPE_C      2.0      Yes          0
# 3        647          56      TYPE_C      2.0       No        1.0
# 4        647          56      TYPE_C      2.0      Yes          0
# 5        647          56      TYPE_C      2.0       No          0
# 6        647          56      TYPE_C      2.0      Yes          0
# 7        647          56      TYPE_C      2.0       No        1.0
# 8        647          56      TYPE_C      2.0       No          0
# 9        647          56      TYPE_C      2.0       No        1.0
# 10       647          56      TYPE_C      2.0       No        2.0
# 11       647          56      TYPE_C      2.0      Yes          0
# 12       647          56      TYPE_C      2.0      Yes          0
# 13       647          56      TYPE_C      2.0       No        1.0
# 14       647          56      TYPE_C      2.0      Yes          0
# 15       647          56      TYPE_C      2.0      Yes          0
# 16       647          56      TYPE_C      2.0      Yes          0
# 17       647          56      TYPE_C      2.0      Yes          0
# 18       647          56      TYPE_C      2.0      Yes          0
# 19       647          56      TYPE_C      2.0      Yes          0
# 20       647          56      TYPE_C      2.0       No        2.0
# 21       647          56      TYPE_C      2.0      Yes          0
# 22       647          56      TYPE_C      2.0       No        1.0
# 23       647          56      TYPE_C      2.0       No          0
# 24       647          56      TYPE_C      2.0      Yes          0
# 25       647          56      TYPE_C      2.0       No        2.0
# 26       647          56      TYPE_C      2.0      Yes          0
# 27       647          56      TYPE_C      2.0      Yes          0
# 28       647          56      TYPE_C      2.0      Yes          0
# 29       647          56      TYPE_C      2.0      Yes          0
# 30       647          56      TYPE_C      2.0      Yes          0
# 31       647          56      TYPE_C      2.0      Yes          0
# 32       647          56      TYPE_C      2.0       No        1.0
# 33       647          56      TYPE_C      2.0      Yes          0
# 34       647          56      TYPE_C      2.0       No          0
# 35       647          56      TYPE_C      2.0      Yes          0
# 36       647          56      TYPE_C      2.0      Yes          0
# 37       647          56      TYPE_C      2.0       No        1.0
# 38       647          56      TYPE_C      2.0       No        2.0
# 39       647          56      TYPE_C      2.0       No        2.0
# 40       647          56      TYPE_C      2.0       No          0
# 41       647          56      TYPE_C      2.0       No          0
# 42       647          56      TYPE_C      2.0       No          0
# 43       647          56      TYPE_C      2.0       No        1.0
# 44       647          56      TYPE_C      2.0       No        2.0
# 45       647          56      TYPE_C      2.0      Yes          0
# 46       647          56      TYPE_C      2.0       No          0
# 47       647          56      TYPE_C      2.0      Yes          0
# 48       647          56      TYPE_C      2.0      Yes          0
# 49       647          56      TYPE_C      2.0      Yes          0
# 50       647          56      TYPE_C      2.0      Yes          0
# 51       647          56      TYPE_C      2.0      Yes          0
# 52       647          56      TYPE_C      2.0      Yes          0
# 53       647          56      TYPE_C      2.0      Yes          0
# 54       647          56      TYPE_C      2.0      Yes          0
# 55       647          56      TYPE_C      2.0      Yes          0
# 56       647          56      TYPE_C      2.0      Yes          0
# 57       647          56      TYPE_C      2.0       No        1.0
# 58       647          56      TYPE_C      2.0      Yes          0
# 59       647          56      TYPE_C      2.0      Yes          0
# 60       647          56      TYPE_C      2.0       No        2.0
# 61       647          56      TYPE_C      2.0       No          0
# 62       647          56      TYPE_C      2.0      Yes          0
# 63       647          56      TYPE_C      2.0      Yes          0
# 64       647          56      TYPE_C      2.0       No          0
# 65       647          56      TYPE_C      2.0       No          0
# 66       647          56      TYPE_C      2.0      Yes          0
# 67       647          56      TYPE_C      2.0      Yes          0
# 68       647          56      TYPE_C      2.0       No        2.0
# 69       647          56      TYPE_C      2.0      Yes          0
# 70       647          56      TYPE_C      2.0       No        1.0
# 71       647          56      TYPE_C      2.0      Yes          0
# 72       647          56      TYPE_C      2.0       No          0
# 73       647          56      TYPE_C      2.0      Yes          0
# 74       647          56      TYPE_C      2.0      Yes          0
# 75       647          56      TYPE_C      2.0       No          0
# 76       647          56      TYPE_C      2.0       No        1.0
# 77       647          56      TYPE_C      2.0       No        2.0
# 78       647          56      TYPE_C      2.0      Yes          0
# 79       647          56      TYPE_C      2.0      Yes          0
# 80       647          56      TYPE_C      2.0       No        2.0
# 81       647          56      TYPE_C      2.0      Yes          0
# 82       647          56      TYPE_C      2.0       No          0
# 83       647          56      TYPE_C      2.0       No          0
# 84       647          56      TYPE_C      2.0      Yes          0
# 85       647          56      TYPE_C      2.0       No          0
# 86       647          56      TYPE_C      2.0      Yes          0
# 87       647          56      TYPE_C      2.0       No          0
# 88       647          56      TYPE_C      2.0       No          0
# 89       647          56      TYPE_C      2.0      Yes          0
# 90       647          56      TYPE_C      2.0      Yes          0
# 91       647          56      TYPE_C      2.0       No        1.0
# 92       647          56      TYPE_C      2.0       No          0
# 93       647          56      TYPE_C      2.0      Yes          0
# 94       647          56      TYPE_C      2.0       No        1.0
# 95       647          56      TYPE_C      2.0       No        1.0
# 96       647          56      TYPE_C      2.0      Yes          0
# 97       647          56      TYPE_C      2.0      Yes          0
# 98       647          56      TYPE_C      2.0      Yes          0
# 99       647          56      TYPE_C      2.0      Yes          0

# %%
num = df_f.select_dtypes(include=np.number).columns

# %%
cat = df_f.select_dtypes(exclude=np.number).columns

# %%
plt.figure(figsize=(20,15))
t = 1
for i in num:
    
        plt.subplot(4,3,t)
        sns.boxplot(df_f[i])
        t+=1
plt.show()

# %% [markdown]
# ## Outlier treatment

# %%
# by capping
for i in num:
    if i != 'num_orders':
        q1,q3=np.quantile(df_f[i],(0.25,0.75))
        iqr = q3-q1
        ul = q3+iqr*1.5
        ll = q1-iqr*1.5
        df_f.loc[df_f[i]>ul,i]=ul
        df_f.loc[df_f[i]<ll,i]=ll

# %%
plt.figure(figsize=(20,15))
t = 1
for i in num:
    
        plt.subplot(4,3,t)
        sns.boxplot(df_f[i])
        t+=1
plt.show()


# num_orders are target variable so we keep it raw

# %% [markdown]
# ## Find Significant Columns using Statistical Tests

# %%
import scipy.stats as st

# %%
num
# Out:
# Index(['id', 'week', 'meal_id', 'checkout_price', 'base_price', 'num_orders',
#        'op_area'],
#       dtype='object')

# %%
sig_features=[]
for i in num:
    if i!= 'num_orders':
        if st.mannwhitneyu(df_f[i],df_f['num_orders'])[1]<0.05:
            print(i,st.mannwhitneyu(df_f[i],df_f['num_orders'])[1])
            sig_features.append(i)

print(sig_features)
# Out:
# id 0.0
# week 0.0
# meal_id 0.0
# checkout_price 0.0
# base_price 0.0
# op_area 0.0
# ['id', 'week', 'meal_id', 'checkout_price', 'base_price', 'op_area']

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
df_f[cat].describe()
# Out:
#         center_id  emailer_for_promotion  homepage_featured   category  \
# count      456548                 456548             456548     456548
# unique         77                      2                  2         14
# top            13                      0                  0  Beverages
# freq         7046                 419498             406693     127890
#
#         cuisine  city_code  region_code center_type discount
# count    456548     456548       456548      456548   456548
# unique        4         51            8           3        2
# top     Italian        590           56      TYPE_A      Yes
# freq     122925      54746       191228      262881   229687

# %%
for i in cat:
    if i!='id':
        mod=ols('num_orders~%s'%i, data=df_f).fit()  # %s means format specifier used to pass String.
        aov=sm.stats.anova_lm(mod)
        print(aov)
# Out:
#                  df        sum_sq       mean_sq           F  PR(>F)
# center_id      76.0  4.571449e+09  6.015064e+07  409.839904     0.0
# Residual   456471.0  6.699451e+10  1.467662e+05         NaN     NaN
#                              df        sum_sq       mean_sq             F  \
# emailer_for_promotion       1.0  5.497009e+09  5.497009e+09  37985.125875
# Residual               456546.0  6.606895e+10  1.447148e+05           NaN
#
#                        PR(>F)
# emailer_for_promotion     0.0
# Residual                  NaN
#                          df        sum_sq       mean_sq             F  PR(>F)
# homepage_featured       1.0  6.206522e+09  6.206522e+09  43353.535674     0.0
# Residual           456546.0  6.535944e+10  1.431607e+05           NaN     NaN
#                 df        sum_sq       mean_sq            F  PR(>F)
# category      13.0  1.307450e+10  1.005731e+09  7849.871954     0.0
# Residual  456534.0  5.849146e+10  1.281207e+05          NaN     NaN
#                 df        sum_sq       mean_sq            F  PR(>F)
# cuisine        3.0  2.288127e+09  7.627091e+08  5026.286988     0.0
# Residual  456544.0  6.927783e+10  1.517440e+05          NaN     NaN
#                  df        sum_sq       mean_sq           F  PR(>F)
# city_code      50.0  2.391677e+09  4.783354e+07  315.664535     0.0
# Residual   456497.0  6.917428e+10  1.515328e+05         NaN     NaN
#                    df        sum_sq       mean_sq            F  PR(>F)
# region_code       7.0  1.269707e+09  1.813868e+08  1178.018924     0.0
# Residual     456540.0  7.029625e+10  1.539761e+05          NaN     NaN
#                    df        sum_sq       mean_sq            F  PR(>F)
# center_type       2.0  6.090329e+08  3.045165e+08  1959.293834     0.0
# Residual     456545.0  7.095693e+10  1.554215e+05          NaN     NaN
#                 df        sum_sq       mean_sq            F  PR(>F)
# discount       1.0  8.939836e+08  8.939836e+08  5775.197282     0.0
# Residual  456546.0  7.067198e+10  1.547971e+05          NaN     NaN

# %% [markdown]
# ## Testing for the Assumptions of Linear Regression

# %% [markdown]
# ## Normality Test:-

# %%
norm_features=[]
for i in num:
    _,p_val=st.shapiro(df_f[i]) # _ is the variable Name.
    if p_val>0.05:
        print(i,p_val)
        norm_features.append(i)
        
print(norm_features)    # there are no normally distributed feature
# Out:
# []

# %%
# rest of the Assumptions are checked after the base model has been created

# %% [markdown]
# # reducing the features by combining
# ### we reduce the 'emailer_for_promotion' & 'homepage_featured' features by combining it as a 'promotion'

# %%
df_f['promotion']=df_f['emailer_for_promotion']+df_f['homepage_featured']

# %%
df_f['promotion']=np.where(df_f.promotion>=1,1,0)

# %% [markdown]
# ## Frequency Encoding

# %%
# we have done freq encoding becz their are many category in each variable of the dataset that shout up the columns

# %%
for i in cat:
    c=(df_f[i].value_counts(normalize=True)*100).to_dict()
    df_f[i]=df_f[i].map(c)

# %%
df_f
# Out:
#                id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560.0     1   1.127154   1885.0          136.83      152.29
# 1       1018704.0     2   1.127154   1885.0          135.83      152.29
# 2       1196273.0     3   1.127154   1885.0          132.92      133.92
# 3       1116527.0     4   1.127154   1885.0          135.86      134.86
# 4       1343872.0     5   1.127154   1885.0          146.50      147.50
# ...           ...   ...        ...      ...             ...         ...
# 456543  1437396.0   141   1.282450   2104.0          583.03      630.53
# 456544  1060716.0   142   1.282450   2104.0          581.03      582.03
# 456545  1029231.0   143   1.282450   2104.0          583.03      581.03
# 456546  1141147.0   144   1.282450   2104.0          582.03      581.03
# 456547  1443704.0   145   1.282450   2104.0          581.03      582.03
#
#         emailer_for_promotion  homepage_featured  num_orders   category  \
# 0                   91.884753          89.080009         177  28.012389
# 1                   91.884753          89.080009         323  28.012389
# 2                   91.884753          89.080009          96  28.012389
# 3                   91.884753          89.080009         163  28.012389
# 4                   91.884753          89.080009         215  28.012389
# ...                       ...                ...         ...        ...
# 456543              91.884753          10.919991          13   2.231310
# 456544              91.884753          89.080009          42   2.231310
# 456545              91.884753          89.080009          40   2.231310
# 456546              91.884753          89.080009          53   2.231310
# 456547              91.884753          89.080009          27   2.231310
#
#           cuisine  city_code  region_code  center_type  op_area   discount  \
# 0       25.893444   2.591841    41.885629    21.814355     2.25  50.309496
# 1       25.893444   2.591841    41.885629    21.814355     2.25  50.309496
# 2       25.893444   2.591841    41.885629    21.814355     2.25  50.309496
# 3       25.893444   2.591841    41.885629    21.814355     2.25  49.690504
# 4       25.893444   2.591841    41.885629    21.814355     2.25  50.309496
# ...           ...        ...          ...          ...      ...        ...
# 456543  22.515705   1.282450    20.723341    57.580145     4.50  50.309496
# 456544  22.515705   1.282450    20.723341    57.580145     4.50  50.309496
# 456545  22.515705   1.282450    20.723341    57.580145     4.50  49.690504
# 456546  22.515705   1.282450    20.723341    57.580145     4.50  49.690504
# 456547  22.515705   1.282450    20.723341    57.580145     4.50  50.309496
#
#         promotion
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 456543          1
# 456544          0
# 456545          0
# 456546          0
# 456547          0
#
# [456548 rows x 17 columns]

# %%
df_f.shape
# Out:
# (456548, 17)

# %%
df_f['promotion']=df_f['promotion'].astype(float)

# %%
df_f.drop(['id','emailer_for_promotion','homepage_featured'],inplace = True , axis = 1)

# %%
df_f
# Out:
#         week  center_id  meal_id  checkout_price  base_price  num_orders  \
# 0          1   1.127154   1885.0          136.83      152.29         177
# 1          2   1.127154   1885.0          135.83      152.29         323
# 2          3   1.127154   1885.0          132.92      133.92          96
# 3          4   1.127154   1885.0          135.86      134.86         163
# 4          5   1.127154   1885.0          146.50      147.50         215
# ...      ...        ...      ...             ...         ...         ...
# 456543   141   1.282450   2104.0          583.03      630.53          13
# 456544   142   1.282450   2104.0          581.03      582.03          42
# 456545   143   1.282450   2104.0          583.03      581.03          40
# 456546   144   1.282450   2104.0          582.03      581.03          53
# 456547   145   1.282450   2104.0          581.03      582.03          27
#
#          category    cuisine  city_code  region_code  center_type  op_area  \
# 0       28.012389  25.893444   2.591841    41.885629    21.814355     2.25
# 1       28.012389  25.893444   2.591841    41.885629    21.814355     2.25
# 2       28.012389  25.893444   2.591841    41.885629    21.814355     2.25
# 3       28.012389  25.893444   2.591841    41.885629    21.814355     2.25
# 4       28.012389  25.893444   2.591841    41.885629    21.814355     2.25
# ...           ...        ...        ...          ...          ...      ...
# 456543   2.231310  22.515705   1.282450    20.723341    57.580145     4.50
# 456544   2.231310  22.515705   1.282450    20.723341    57.580145     4.50
# 456545   2.231310  22.515705   1.282450    20.723341    57.580145     4.50
# 456546   2.231310  22.515705   1.282450    20.723341    57.580145     4.50
# 456547   2.231310  22.515705   1.282450    20.723341    57.580145     4.50
#
#          discount  difference promotion
# 0       50.309496   74.569815         0
# 1       50.309496   74.569815         0
# 2       50.309496   74.569815         0
# 3       49.690504   16.135872         0
# 4       50.309496   74.569815         0
# ...           ...         ...       ...
# 456543  50.309496   74.569815         1
# 456544  50.309496   74.569815         0
# 456545  49.690504    8.082830         0
# 456546  49.690504   16.135872         0
# 456547  50.309496   74.569815         0
#
# [456548 rows x 15 columns]

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 456548 entries, 0 to 456547
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   week            456548 non-null  int64
#  1   center_id       456548 non-null  float64
#  2   meal_id         456548 non-null  float64
#  3   checkout_price  456548 non-null  float64
#  4   base_price      456548 non-null  float64
#  5   num_orders      456548 non-null  int64
#  6   category        456548 non-null  float64
#  7   cuisine         456548 non-null  float64
#  8   city_code       456548 non-null  float64
#  9   region_code     456548 non-null  float64
#  10  center_type     456548 non-null  float64
#  11  op_area         456548 non-null  float64
#  12  discount        456548 non-null  float64
#  13  difference      456548 non-null  float64
#  14  promotion       456548 non-null  object
# dtypes: float64(12), int64(2), object(1)
# memory usage: 55.7+ MB

# %% [markdown]
# ## Spliting the dataset for Validation

# %%
from sklearn.model_selection import train_test_split

# %%
cat = df_f[['center_id', 'category','promotion'
       'cuisine', 'city_code', 'region_code', 'center_type', 'discount'
       ]]

# %%
x = df_f.drop('num_orders',axis = 1)
y = df_f['num_orders']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.30,random_state=10)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((319583, 13), (136965, 13), (319583,), (136965,))

# %%
num = df_f[['week', 'meal_id', 'checkout_price', 'base_price', 'op_area']]

# %% [markdown]
# ## scalering

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
for i in num:
    xtrain.loc[:,i]=sc.fit_transform(pd.DataFrame(xtrain.loc[:,i]))
    xtest.loc[:,i]=sc.transform(pd.DataFrame(xtest.loc[:,i]))

# %%
y
# Out:
# 0         177
# 1         323
# 2          96
# 3         163
# 4         215
#          ...
# 456543     13
# 456544     42
# 456545     40
# 456546     53
# 456547     27
# Name: num_orders, Length: 456548, dtype: int64

# %% [markdown]
# ## Applying the base Model

# %%
import statsmodels.api as sma
from statsmodels.formula.api import ols

# %%
x_train = sma.add_constant(xtrain)
x_test = sma.add_constant(xtest)

# %%
modelstats = sma.OLS(ytrain,x_train).fit()

# %%
modelstats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             num_orders   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     6406.
# Date:                Thu, 22 Dec 2022   Prob (F-statistic):               0.00
# Time:                        21:26:08   Log-Likelihood:            -2.3287e+06
# No. Observations:              319583   AIC:                         4.657e+06
# Df Residuals:                  319569   BIC:                         4.658e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -381.7945    116.621     -3.274      0.001    -610.369    -153.220
# week              -2.2532      0.626     -3.599      0.000      -3.480      -1.026
# center_id        318.1880      6.196     51.353      0.000     306.044     330.332
# meal_id            1.4970      0.640      2.341      0.019       0.243       2.751
# checkout_price  -125.4555      2.626    -47.775      0.000    -130.602    -120.309
# base_price        40.0345      2.775     14.428      0.000      34.596      45.473
# category           0.7640      0.086      8.884      0.000       0.595       0.933
# cuisine           15.9246      0.618     25.773      0.000      14.714      17.136
# city_code          4.7768      0.176     27.115      0.000       4.432       5.122
# region_code       -0.2474      0.058     -4.252      0.000      -0.361      -0.133
# center_type       -0.6049      0.037    -16.344      0.000      -0.677      -0.532
# op_area           37.0789      0.865     42.882      0.000      35.384      38.774
# discount          -4.3423      2.309     -1.881      0.060      -8.867       0.183
# promotion        314.1021      2.056    152.806      0.000     310.073     318.131
# ==============================================================================
# Omnibus:                   439405.374   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        409228373.848
# Skew:                           7.511   Prob(JB):                         0.00
# Kurtosis:                     177.661   Cond. No.                     1.45e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# We can see that the Condition Number is very Large, which indicates the presence of Multicollinearity.
# We need to cross-check the Assumptions of Linear Regression.

# %%
modelstats.params[1:].sort_values().plot(kind='barh')

# hence the checkout_price is showing -ve relation with the model and center_id , promotion is showing high relation
# Out:
# <AxesSubplot:>

# %%
ytrain
# Out:
# 250133     14
# 222848    203
# 435889     68
# 321089    177
# 52108     378
#          ...
# 93553     135
# 443712    136
# 356879     13
# 236669     55
# 345353     26
# Name: num_orders, Length: 319583, dtype: int64

# %%
## Hence R-square is very low so we try to uplift it by transforming the model

# %% [markdown]
# ## Checking Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
numeric=xtrain.select_dtypes(include=np.number)
numeric.values
# Out:
# array([[ 9.45977449e-01,  1.29033530e+00,  7.67582951e-01, ...,
#         -3.40474592e-02,  4.96905035e+01,  0.00000000e+00],
#        [-7.64834686e-01,  1.32319055e+00,  9.95952047e-01, ...,
#         -1.50988222e+00,  4.96905035e+01,  0.00000000e+00],
#        [-2.58819829e-01,  1.29800152e+00,  1.24259067e+00, ...,
#         -3.40474592e-02,  4.96905035e+01,  0.00000000e+00],
#        ...,
#        [-7.64834686e-01,  1.22834839e+00,  1.54038397e+00, ...,
#          7.94782920e-02,  5.03094965e+01,  0.00000000e+00],
#        [-1.56000089e+00,  1.01347503e+00,  1.10922312e+00, ...,
#         -1.39635647e+00,  4.96905035e+01,  0.00000000e+00],
#        [-2.82915774e-01,  1.33589458e+00, -1.50880019e+00, ...,
#         -1.16930497e+00,  5.03094965e+01,  0.00000000e+00]])

# %%
vif=[variance_inflation_factor(numeric.values, i) for i in range(numeric.shape[1])]

# %%
pd.DataFrame({'VIF':vif}, index=numeric.columns).sort_values(by='VIF', ascending=False)
# Out:
#                        VIF
# discount        806.491929
# cuisine         607.648146
# center_id       172.588861
# base_price       17.585987
# checkout_price   14.773450
# region_code       8.603819
# center_type       7.356491
# category          4.643069
# city_code         2.333417
# op_area           1.909720
# promotion         1.597575
# meal_id           1.046131
# week              1.001943

# %%
# We can see that discount, cuisine, center_id, base_price, checkout_price 
# have VIF greater than 10, so these features can be dropped.

# %% [markdown]
# # Checking Normality of Residuals:-

# %%
residual=modelstats.resid
residual
# Out:
# 250133     55.198821
# 222848     39.975448
# 435889   -209.440937
# 321089    -24.411784
# 52108     152.527745
#              ...
# 93553    -394.303031
# 443712    -15.284691
# 356879     23.426195
# 236669    -57.494433
# 345353   -236.315136
# Length: 319583, dtype: float64

# %%
sns.distplot(residual)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
qqplot(residual, line='r')
plt.show()

# %%
# As we can see the Blue dots diverging from the red line, which shows the residuals don't have normal distribution.

# %%
import scipy.stats as stats
stats.shapiro(residual)
# Out:
# ShapiroResult(statistic=0.6598323583602905, pvalue=0.0)

# %%
# Residual Distribution is not Normal. Hence it doesn't satisfy the Normality Assumption.

# %% [markdown]
# # HeteroSkedasticity

# %%
y_pred_train= modelstats.predict(x_train)

# %%
sns.residplot(ytrain,y_pred_train)
# Out:
# <AxesSubplot:xlabel='num_orders'>

# %%
# Breusch Pagan Test: To check for Hetero Skedasticity of Residual
# Ho: Homoscedasticity is Present
# Ha: Heteroscedasticity is Present

# %%
import statsmodels.stats.api as sst

_, p_value,_,f_p_value_ = sst.het_breuschpagan(residual,modelstats.model.exog)
print(p_value,'\n' ,f_p_value_)
# Out:
# 0.0
#  0.0

# %%
# Heteroskedasticity is present in the Model.

# %%
## Hence we are not apply further Assumption on that

# %% [markdown]
# ## Transformation

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer()

# %%
xtrain_tranform=pd.DataFrame(pt.fit_transform(xtrain),columns=xtrain.columns)

# %%
xtest_tranform=pd.DataFrame(pt.transform(xtest),columns=xtest.columns)
xtest_tranform
# Out:
#             week  center_id   meal_id  checkout_price  base_price  category  \
# 0       0.920805  -0.325782 -1.662295       -1.331774   -1.267735  1.423261
# 1      -1.028485   0.472565  0.851873       -0.952025   -0.654238 -1.894593
# 2      -1.307390   1.029665 -0.173244        1.186343    1.334028 -0.188628
# 3      -0.512056   0.300043  0.750703        1.488752    1.349493 -0.521434
# 4      -0.155118   1.368492 -0.310594       -1.440090   -1.585944  1.423261
# ...          ...        ...       ...             ...         ...       ...
# 136960  1.370365  -0.560951  1.543168        0.139521    0.016217 -0.181515
# 136961 -0.794645   1.163645 -0.893722        1.046564    0.908506 -0.383210
# 136962  0.747205  -1.976766  0.153813       -0.146076   -0.302409  1.423261
# 136963 -0.441026  -1.976766  0.444681       -0.261299   -0.410599 -0.176105
# 136964 -0.935115   1.212251 -1.589215       -0.276976   -0.182425 -0.176105
#
#          cuisine  city_code  region_code  center_type   op_area  discount  \
# 0       1.259266  -0.904490    -0.694611     0.858455  0.882454   0.99295
# 1       0.386618   0.427973     1.056042    -1.130798  1.196945   0.99295
# 2      -1.467918  -0.655731     1.056042     0.858455  0.882454   0.99295
# 3      -1.467918  -0.775663    -2.027149     0.858455  0.561252   0.99295
# 4       0.386618   0.928748     1.056042     0.858455  1.960593  -1.00710
# ...          ...        ...          ...          ...       ...       ...
# 136960  1.259266  -0.961517    -0.312491     0.858455  0.005895   0.99295
# 136961 -0.443281   0.432824     1.056042    -1.199814  0.452421  -1.00710
# 136962 -0.443281   1.486518    -0.312491    -1.130798 -2.146312  -1.00710
# 136963 -0.443281   1.486518    -0.312491    -1.130798 -2.146312  -1.00710
# 136964 -0.443281  -0.629506     1.056042     0.858455 -0.342923   0.99295
#
#         promotion
# 0       -0.417310
# 1       -0.417310
# 2        2.396301
# 3       -0.417310
# 4       -0.417310
# ...           ...
# 136960  -0.417310
# 136961  -0.417310
# 136962  -0.417310
# 136963  -0.417310
# 136964  -0.417310
#
# [136965 rows x 13 columns]

# %%
x_train = sma.add_constant(xtrain)
x_test = sma.add_constant(xtest)

# %%
# sma.OLS(ytrain,xtrain_tranform).fit().summary()

# %% [markdown]
# ## linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
model_lr=lr.fit(xtrain,ytrain)

# %%
pred = model_lr.predict(xtest)

# %%
from sklearn.metrics import r2_score  , mean_squared_error , mean_absolute_percentage_error , mean_squared_error

# %%
def validation(test,pred):
    r2 = r2_score(test,pred)
    print('R-Square: ',r2)
    n = x_test.shape[0]
    k = x_test.shape[1]
    adj_r2= 1-((1-r2)*(n-1)/(n-k-1))
    print('Adjusted R2: ',adj_r2)
    print('MSE: ',mean_squared_error(test,pred))
    print('RMSE: ',mean_squared_error(test,pred)**0.5)
    print('MAPE: ',mean_absolute_percentage_error(test,pred))

# %%
validation(ytest,pred)
# Out:
# R-Square:  0.20773498019617065
# Adjusted R2:  0.2076539892485456
# MSE:  122785.74028674772
# RMSE:  350.4079626474657
# MAPE:  2.4615950151311052

# %%
# this model is underfit in this case

# %% [markdown]
# # applying Transformed dataset in linear Regression

# %%
model_lrp=lr.fit(xtrain_tranform,ytrain)

# %%
pred = model_lrp.predict(xtest_tranform)

# %%
validation(ytest,pred)
# Out:
# R-Square:  0.22121590136511482
# Adjusted R2:  0.22113628853283374
# MSE:  120696.45848823294
# RMSE:  347.4139583957918
# MAPE:  2.3672306444378197

# %%
# hence r2 square inc by only 2%
# RMSE - reduce by 3

# %% [markdown]
# ## feature selection

# %%
from sklearn.feature_selection import RFE

# %%
 rfe = RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
X=pd.concat([xtrain,xtest],axis = 0).sort_index()

# %%
Y = pd.DataFrame(y)

# %%
rfe.fit(X,Y)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
pd.Series(rfe.ranking_,index=xtrain.columns).sort_values().index[0:5]
# Out:
# Index(['center_id', 'checkout_price', 'base_price', 'op_area', 'promotion'], dtype='object')

# %%
rfe_selector = df_f[['center_id', 'checkout_price', 'base_price', 'op_area', 'promotion']]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(rfe_selector,y,test_size=.30,random_state=10)

# %%
model_rfe=lr.fit(xtrain,ytrain)

# %%
pred1 = model_rfe.predict(xtest)

# %%
validation(ytest,pred1)   # model is not performing after taking best parameter from rfe
# Out:
# R-Square:  0.20258046308991484
# Adjusted R2:  0.20249894521100475
# MSE:  123584.59064981063
# RMSE:  351.546000759233
# MAPE:  2.4408160180978817

# %% [markdown]
# ## other models

# %% [markdown]
# ## DecisionTree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
model_dt = dt.fit(xtrain,ytrain)

# %%
pred2=model_dt.predict(xtest)

# %%
validation(ytest,pred2)
# Out:
# R-Square:  0.4380304484817604
# Adjusted R2:  0.4379729999697396
# MSE:  87094.40108672729
# RMSE:  295.11760551808374
# MAPE:  1.0657030978438449

# %%
# Hence in the Decision Tree Regressor we have seen the R2 improve but RMSE remain almost same

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
model_rf = rf.fit(xtrain,ytrain).predict(xtest)

# %%
validation(ytest,model_rf)
# Out:
# R-Square:  0.863693610307203
# Adjusted R2:  0.8636796761016119
# MSE:  21124.85159118607
# RMSE:  145.34390799474903
# MAPE:  0.4843422988310351

# %% [markdown]
# # XGBRegressor

# %%
from xgboost import XGBRegressor

# %%
xg = XGBRegressor()

# %%
pred_xg = xg.fit(xtrain,ytrain).predict(xtest)

# %%
validation(ytest,pred_xg)
# Out:
# r2_score:  0.8471975444789651
# Adujusted R2:  0.8471808080527568
# MAP 0.6218977190535254
# RMSE:  153.88769424639398

# %%
from sklearn.model_selection import GridSearchCV

# %%
# parameters = {
#     'n_estimators': [100, 150, 200, 250, 300],
#     'max_depth': [1,2,3,4],
# }
# regr = RandomForestRegressor(random_state=0)

# clf = GridSearchCV(regr, parameters)
# clf.fit(xtrain, ytrain)

# %%
# pred_cv = clf.predict(xtest)

# %%
# validation(ytest,pred_cv)
